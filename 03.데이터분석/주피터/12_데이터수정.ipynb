# %%
import pandas as pd
df = pd.read_csv('data/score.csv', index_col='지원번호')

# %%
df2=df.copy()
filt = df2['학교']=='북산고'
df2.loc[filt, '학교']='산북고'
filt = df2['학교']=='능남고'
df2.loc[filt, '학교']='남능고'
df2
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  산북고  197   90   85  100  95  85      Python
# 2번    정대만  산북고  184   40   35   50  55  25        Java
# 3번    송태섭  산북고  168   80   75   70  80  75  Javascript
# 4번    서태웅  산북고  187   40   60   70  75  80         NaN
# 5번    강백호  산북고  188   15   20   10  35  10         NaN
# 6번    변덕규  남능고  202   80  100   95  85  80           C
# 7번    황태산  남능고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  남능고  190  100   85   90  95  95          C#

# %%
df3 = df.copy()
#df3['학교'] = '산북고'
df3['학교'].replace({'북산고':'산북고', '능남고':'남능고'}, inplace=True)
df3
# Out:
# C:\Users\AIPM2\AppData\Local\Temp\ipykernel_17700\1767151649.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3['학교'].replace({'북산고':'산북고', '능남고':'남능고'}, inplace=True)
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  산북고  197   90   85  100  95  85      Python
# 2번    정대만  산북고  184   40   35   50  55  25        Java
# 3번    송태섭  산북고  168   80   75   70  80  75  Javascript
# 4번    서태웅  산북고  187   40   60   70  75  80         NaN
# ...

# %%
df4=df.copy()
df4['학교'].replace({'학교':'북산고'})
# Out:
# 지원번호
# 1번    북산고
# 2번    북산고
# 3번    북산고
# 4번    북산고
# 5번    북산고
# 6번    능남고
# 7번    능남고
# 8번    능남고
# Name: 학교, dtype: object

# %%
import numpy as np

df3=df.copy()
df3.replace({'학교':{'북산고':'산북고', '능남고':'남능고'}}, inplace=True)
df3.loc['9번'] = ['홍길동', '남능고', 195, 0, 0, 0, 0, 0,np.nan]
df3
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  산북고  197   90   85  100  95  85      Python
# 2번    정대만  산북고  184   40   35   50  55  25        Java
# 3번    송태섭  산북고  168   80   75   70  80  75  Javascript
# 4번    서태웅  산북고  187   40   60   70  75  80         NaN
# 5번    강백호  산북고  188   15   20   10  35  10         NaN
# 6번    변덕규  남능고  202   80  100   95  85  80           C
# 7번    황태산  남능고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  남능고  190  100   85   90  95  95          C#
# 9번    홍길동  남능고  195    0    0    0   0   0         NaN

# %%
df4 = df.copy()
df4['SW특기'] = df['SW특기'].str.capitalize()  #upper, lower, capitalize
df4['학교'] = df4['학교'] + '등학교'
df4['총점'] = df4['국어'] + df4['영어'] + df4['수학'] + df4['과학'] + df4['사회']
df4['평균'] = df4['총점']/5
df4['결과'] = 'Fail'
filt = df4['평균'] >= 70
df4.loc[filt, '결과'] = 'Pass'
df4
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총점    평균    결과
# 지원번호
# 1번    채치수  북산고등학교  197   90   85  100  95  85      Python  455  91.0  Pass
# 2번    정대만  북산고등학교  184   40   35   50  55  25        Java  205  41.0  Fail
# 3번    송태섭  북산고등학교  168   80   75   70  80  75  Javascript  380  76.0  Pass
# 4번    서태웅  북산고등학교  187   40   60   70  75  80         NaN  325  65.0  Fail
# 5번    강백호  북산고등학교  188   15   20   10  35  10         NaN   90  18.0  Fail
# 6번    변덕규  능남고등학교  202   80  100   95  85  80           C  440  88.0  Pass
# 7번    황태산  능남고등학교  188   55   65   45  40  35      Python  240  48.0  Fail
# 8번    윤대협  능남고등학교  190  100   85   90  95  95          C#  465  93.0  Pass

# %%
filt = df4['결과'] == 'Pass'
df4[filt]
# Out:
#        이름      학교    키   국어   영어   수학  과학  사회        SW특기   총점    평균    결과
# 지원번호
# 1번    채치수  북산고등학교  197   90   85  100  95  85      Python  455  91.0  Pass
# 3번    송태섭  북산고등학교  168   80   75   70  80  75  Javascript  380  76.0  Pass
# 6번    변덕규  능남고등학교  202   80  100   95  85  80           C  440  88.0  Pass
# 8번    윤대협  능남고등학교  190  100   85   90  95  95          C#  465  93.0  Pass

# %% [markdown]
# 데이터 삭제

# %%
df5 = df.copy()
df5.drop(columns=['키', 'SW특기'])
# Out:
#        이름   학교   국어   영어   수학  과학  사회
# 지원번호
# 1번    채치수  북산고   90   85  100  95  85
# 2번    정대만  북산고   40   35   50  55  25
# 3번    송태섭  북산고   80   75   70  80  75
# 4번    서태웅  북산고   40   60   70  75  80
# 5번    강백호  북산고   15   20   10  35  10
# 6번    변덕규  능남고   80  100   95  85  80
# 7번    황태산  능남고   55   65   45  40  35
# 8번    윤대협  능남고  100   85   90  95  95

# %%
df5.drop(index='4번')
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df5.drop(index=df5.index[0:5])
# Out:
#        이름   학교    키   국어   영어  수학  과학  사회    SW특기
# 지원번호
# 6번    변덕규  능남고  202   80  100  95  85  80       C
# 7번    황태산  능남고  188   55   65  45  40  35  PYTHON
# 8번    윤대협  능남고  190  100   85  90  95  95      C#

# %%
df5.drop(columns=df5.columns[0:3])
# Out:
#        국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번     90   85  100  95  85      Python
# 2번     40   35   50  55  25        Java
# 3번     80   75   70  80  75  Javascript
# 4번     40   60   70  75  80         NaN
# 5번     15   20   10  35  10         NaN
# 6번     80  100   95  85  80           C
# 7번     55   65   45  40  35      PYTHON
# 8번    100   85   90  95  95          C#

# %%
cols = df5.columns
df5.drop(columns=cols[0:3])
# Out:
#        국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번     90   85  100  95  85      Python
# 2번     40   35   50  55  25        Java
# 3번     80   75   70  80  75  Javascript
# 4번     40   60   70  75  80         NaN
# 5번     15   20   10  35  10         NaN
# 6번     80  100   95  85  80           C
# 7번     55   65   45  40  35      PYTHON
# 8번    100   85   90  95  95          C#

# %%
df6 = df.copy()
filt = df6['학교']=='능남고'
df6.drop(index=df6[filt].index)
#==
#idx = df6[filt].index
#df6.drop(index=idx)
# Out:
#        이름   학교    키  국어  영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197  90  85  100  95  85      Python
# 2번    정대만  북산고  184  40  35   50  55  25        Java
# 3번    송태섭  북산고  168  80  75   70  80  75  Javascript
# 4번    서태웅  북산고  187  40  60   70  75  80         NaN
# 5번    강백호  북산고  188  15  20   10  35  10         NaN

# %%
#출력순서 바꾸기 - SW특기 맨 앞으로 배치하기
df7 = df.copy()
cols = list(df7.columns)  #list로 바꿔줘야함
df8 = df7[[cols[-1]] + cols[:-1]]
df8
# Out:
#             SW특기   이름   학교    키   국어   영어   수학  과학  사회
# 지원번호
# 1번        Python  채치수  북산고  197   90   85  100  95  85
# 2번          Java  정대만  북산고  184   40   35   50  55  25
# 3번    Javascript  송태섭  북산고  168   80   75   70  80  75
# 4번           NaN  서태웅  북산고  187   40   60   70  75  80
# 5번           NaN  강백호  북산고  188   15   20   10  35  10
# 6번             C  변덕규  능남고  202   80  100   95  85  80
# 7번        PYTHON  황태산  능남고  188   55   65   45  40  35
# 8번            C#  윤대협  능남고  190  100   85   90  95  95

# %%
#총점, 평균, 결과만 가져오기
df9 = df4.copy()
df9 = df9[['총점', '평균', '결과']]
df9
# Out:
#        총점    평균    결과
# 지원번호
# 1번    455  91.0  Pass
# 2번    205  41.0  Fail
# 3번    380  76.0  Pass
# 4번    325  65.0  Fail
# 5번     90  18.0  Fail
# 6번    440  88.0  Pass
# 7번    240  48.0  Fail
# 8번    465  93.0  Pass

# %%
#col 이름 수정
df9.columns = ['Total', 'Average', 'Result']
df9
# Out:
#       Total  Average Result
# 지원번호
# 1번      455     91.0   Pass
# 2번      205     41.0   Fail
# 3번      380     76.0   Pass
# 4번      325     65.0   Fail
# 5번       90     18.0   Fail
# 6번      440     88.0   Pass
# 7번      240     48.0   Fail
# 8번      465     93.0   Pass
